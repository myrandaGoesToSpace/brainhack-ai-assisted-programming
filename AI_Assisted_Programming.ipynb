# %% [markdown]
# # AI-Assisted Programming for Neuroscience

# %% [markdown]
# ## Mini Project Goal
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Accessing the Data
#
# The next step of our project should be accessing our data. Let's see what ChatGPT can find for us.
#
# Prompt: *How do I access ADNI Data using Python?*
